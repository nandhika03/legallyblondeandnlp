# %% [markdown]
# ### Stopwords
# - These are words like 'the' 'is' 'and' in text that mostly hold less meaning
# - Before performing lemmatization or stemming it is best practice to remove these stopwords

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer, SnowballStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Nandhika\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
pr = PorterStemmer()
lr = WordNetLemmatizer()

# %%
para = """
    A Delta Gamma/Sigma Chi barbecue in full swing. Beautiful
    college students drink beer and mingle, trying to figure out
    who they're going to sleep with next.
    The main wall of the living room has been designated as a
    "Model Wall" of Delta Gamma girls -- ELLE smiles at us from a
    Hawaiian Tropic ad and a Miss June USC calendar photo. A
    cover of an Italian Vogue shows a blonde sexpot MARGOT; a USC
    cheerleader poster displays a hard-bodied non-blonde SERENA
    in a pom-pom pose.
    Serena walks up, fending off an admirer.
"""
print(para)
# Out:
#     A Delta Gamma/Sigma Chi barbecue in full swing. Beautiful
#     college students drink beer and mingle, trying to figure out
#     who they're going to sleep with next.
#     The main wall of the living room has been designated as a
#     "Model Wall" of Delta Gamma girls -- ELLE smiles at us from a
#     Hawaiian Tropic ad and a Miss June USC calendar photo. A
#     cover of an Italian Vogue shows a blonde sexpot MARGOT; a USC
#     cheerleader poster displays a hard-bodied non-blonde SERENA
#     in a pom-pom pose.
#     Serena walks up, fending off an admirer.

# %% [markdown]
# #### using stemming

# %%
sents = sent_tokenize(para)
for i in range(len(sents)):
    words = nltk.word_tokenize(sents[i])
    words = [pr.stem(w) for w in words if w not in set(stopwords.words('english'))]
    sents[i] = ' '.join(words)

# %%
sents
# Out:
# ['a delta gamma/sigma chi barbecu full swing .',
#  "beauti colleg student drink beer mingl , tri figur 're go sleep next .",
#  "the main wall live room design `` model wall '' delta gamma girl -- ell smile us hawaiian tropic ad miss june usc calendar photo .",
#  'a cover italian vogu show blond sexpot margot ; usc cheerlead poster display hard-bodi non-blond serena pom-pom pose .',
#  'serena walk , fend admir .']

# %% [markdown]
# #### using lemmitization

# %%
sents = sent_tokenize(para)
for i in range(len(sents)):
    words = word_tokenize(sents[i])
    words = [lr.lemmatize(w) for w in words if w not in set(stopwords.words('english'))]
    sents[i] = ' '.join(words)

# %%
sents
# Out:
# ['A Delta Gamma/Sigma Chi barbecue full swing .',
#  "Beautiful college student drink beer mingle , trying figure 're going sleep next .",
#  "The main wall living room designated `` Model Wall '' Delta Gamma girl -- ELLE smile u Hawaiian Tropic ad Miss June USC calendar photo .",
#  'A cover Italian Vogue show blonde sexpot MARGOT ; USC cheerleader poster display hard-bodied non-blonde SERENA pom-pom pose .',
#  'Serena walk , fending admirer .']
